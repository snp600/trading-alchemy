# %%
# %pylab inline
import matplotlib.pyplot as plt
import pandas as pd
import os

PATH_TO_DATA = os.getcwd()
PATH_TO_DATA = PATH_TO_DATA[:-PATH_TO_DATA[::-1].find("/")]
PATH_TO_DATA += "data/2018-full-1d/"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
btc_df = pd.read_csv(PATH_TO_DATA + "BTCUSDT_2018_1DAY_Binance.csv", sep='\t')
eth_df = pd.read_csv(PATH_TO_DATA + "ETHUSDT_2018_1DAY_Binance.csv", sep='\t')
eos_df = pd.read_csv(PATH_TO_DATA + "EOSUSDT_2018_1DAY_Binance.csv", sep='\t')

# %%
btc_open = btc_df["open"].values
eth_open = eth_df["open"].values
eos_open = eos_df["open"].values

plt.figure(figsize(13,6))
plt.scatter(btc_open, eth_open)
plt.show()

# %%
from scipy.stats.stats import pearsonr, spearmanr

print("eth/btc")
print(spearmanr(btc_open,eth_open)[0])
print(pearsonr(btc_open,eth_open)[0])
print("eos/btc")
print(spearmanr(btc_open[:219],eos_open)[0])
print(pearsonr(btc_open[:219],eos_open)[0])
# Out:
# eth/btc
# 0.913160997881185
# 0.8903427524115283
# eos/btc
# 0.7367806505421185
# 0.8476204226457069

# %%
btc_half = btc_df["open"].tail(180).values
eth_half = eth_df["open"].tail(180).values

plt.figure(figsize(13,6))
plt.scatter(btc_half, eth_half)
plt.show()

# %%
data = {'btc_open'  : btc_df["open"],
        'btc_close' : btc_df["close"],
        'change(btc), %' : round(btc_df["close"]/btc_df["open"]*100-100, 2), 
        'eth_open'  : eth_df["open"],
        'eth_close' : eth_df["close"],
        'change(eth), %' : round(eth_df["close"]/eth_df["open"]*100-100, 2),
        'eos_open'  : eos_df["open"],
        'eos_close' : eos_df["close"],
        'change(eos), %' : round(eos_df["close"]/eos_df["open"]*100-100, 2)
       }
merged = pd.DataFrame(data=data)
merged.head()
# Out:
#    btc_open  btc_close  change(btc), %  eth_open  eth_close  change(eth), %  \
# 0  13715.65   13380.00           -2.45    733.01     754.99            3.00
# 1  13382.16   14675.11            9.66    754.99     855.28           13.28
# 2  14690.00   14919.51            1.56    855.13     934.03            9.23
# 3  14919.51   15059.54            0.94    934.03     940.00            0.64
# 4  15059.56   16960.39           12.62    940.00     959.30            2.05
#
#    eos_open  eos_close  change(eos), %
# 0   12.4900    11.4788           -8.10
# 1   11.4853    12.1112            5.45
# 2   12.1113    11.8968           -1.77
# 3   11.8712    12.2353            3.07
# 4   12.2351    12.2048           -0.25

# %%
print(spearmanr(merged['change(btc), %'],merged['change(eth), %'])[0])
print(pearsonr(merged['change(btc), %'],merged['change(eth), %'])[0])

print("mean(change):")
print(np.mean(abs(merged['change(btc), %'])))
print(np.mean(abs(merged['change(eth), %'])))
print(np.mean(abs(merged['change(eos), %'])))
# Out:
# 0.8263794710757498
# 0.8147074846423493
# mean(change):
# 3.056475409836066
# 4.183087431693989
# 4.353881278538812

# %%
#0) fall(>5%)
#1) down(2-5%)
#2) flat
#3) up(2-5%)
#4) surge(>5%)

a = 1.5
b = 4.5
def get_index(value):
    index = 2
    if value > a:
        index = (4 if value > b else 3)
    elif value < -a:
        index = (0 if value < -b else 1)
    return index
        
def magic_matrix(x, y, normalized=True, percents=True):
    res = np.zeros((5,5))
    for k in range(len(x)):
        i = get_index(x[k])
        j = get_index(y[k])
        res[i,j] += 1
    if normalized:
        res /= sum(res)
    if percents:
        res *= 100
    return res.round(1)

# %%
import seaborn as sns;
sns.set()

mm = magic_matrix(merged['change(btc), %'], merged['change(eth), %'])
ax = sns.heatmap(mm, annot=True, square=True, fmt='g', cmap='cool')
ax.xaxis.tick_top()
plt.text(0.5, -0.1, "Joint distribution of ETH/BTC in 2018 by price change, %",
         horizontalalignment='center',
         fontsize=15,
         transform = ax.transAxes,
         fontweight='bold')
plt.text(0.5, 1.1, "Bitcoin", horizontalalignment='center', fontsize=12, 
         transform = ax.transAxes, fontweight='bold')
plt.text(-0.25, 0.487, "Ethereum", horizontalalignment='center', fontsize=12, 
         transform = ax.transAxes, fontweight='bold')

ax.xaxis.set_ticks_position('none')
ax.set_xticklabels(["fall (>5%)", "down (2-5%)","flat", "up (2-5%)", "surge (>5%)"], size=10)
ax.set_yticklabels(["fall (>5%)", "down (2-5%)","flat", "up (2-5%)", "surge (>5%)"], rotation=0, size=10)
# Out:
# [Text(0, 0.5, 'fall (>5%)'),
#  Text(0, 1.5, 'down (2-5%)'),
#  Text(0, 2.5, 'flat'),
#  Text(0, 3.5, 'up (2-5%)'),
#  Text(0, 4.5, 'surge (>5%)')]

# %%
print(str(sum(np.diag(mm)))+"%")
print(str(sum(np.diag(mm)) + sum(np.diag(mm, k=1)) + sum(np.diag(mm, k=-1))) + "%")
# Out:
# 61.8%
# 94.4%

# %%
mm = magic_matrix(merged['change(btc), %'], merged['change(eos), %'])
ax = sns.heatmap(mm, annot=True, square=True, fmt='g', cmap='cool')
ax.xaxis.tick_top()
plt.text(0.5, -0.1, "Joint distribution of EOS/BTC in Q3/Q4 2018 by price change, %",
         horizontalalignment='center',
         fontsize=15,
         transform = ax.transAxes,
         fontweight='bold')
plt.text(0.5, 1.1, "Bitcoin", horizontalalignment='center', fontsize=12, 
         transform = ax.transAxes, fontweight='bold')
plt.text(-0.25, 0.487, "EOS", horizontalalignment='center', fontsize=12, 
         transform = ax.transAxes, fontweight='bold')

ax.xaxis.set_ticks_position('none')
ax.set_xticklabels(["fall (>5%)", "down (2-5%)","flat", "up (2-5%)", "surge (>5%)"], size=10)
ax.set_yticklabels(["fall (>5%)", "down (2-5%)","flat", "up (2-5%)", "surge (>5%)"], rotation=0, size=10)
# Out:
# [Text(0, 0.5, 'fall (>5%)'),
#  Text(0, 1.5, 'down (2-5%)'),
#  Text(0, 2.5, 'flat'),
#  Text(0, 3.5, 'up (2-5%)'),
#  Text(0, 4.5, 'surge (>5%)')]

# %%
print(str(sum(np.diag(mm)))+"%")
print(str(sum(np.diag(mm)) + sum(np.diag(mm, k=1)) + sum(np.diag(mm, k=-1))) + "%")
# Out:
# 36.9%
# 71.0%
